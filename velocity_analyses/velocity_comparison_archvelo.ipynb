# %%
import scanpy as sc
import ArchVelo as av
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
av_data = sc.read_h5ad(rf"C:\Users\Nikla\Documents\MoBi_Master_FS.3\Internship AG Höfer\DynaVelo_testing\data\archvelo_final_result_rooted.h5ad")

# %%
av_data
# Out:
# AnnData object with n_obs × n_vars = 5380 × 1454
# ...

# %%
av.velocity_embedding_stream(av_data, 
                             show=True, 
                             color = 'cell_type', 
                             title = 'ArchVelo result')
# Out:
# computing velocity embedding
#     finished (0:00:03) --> added
#     'velo_s_norm_umap', embedded velocity vectors (adata.obsm)
